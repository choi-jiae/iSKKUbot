# %%
import pandas as pd
import json

result = pd.read_json("/kaggle/input/eval-results/evaluation_results.json")

# %%
result.columns
# Out:
# Index(['question', 'true_answer', 'context', 'generated_answer',
#        'test_settings', 'eval_score_GPT4o-mini'],
#       dtype='object')

# %%
average_score = result["eval_score_GPT4o-mini"].mean()
average_score
# Out:
# 3.50314465408805
